# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#mounting google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading data and cheking five rows 
df_car=pd.read_csv("/content/drive/MyDrive/CarPrice_Assignment.csv")
df_car.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
X=df_car.iloc[:,:-1]
y=df_car.iloc[:,-1]

# %%
df_car.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
X.drop(X.select_dtypes(include='object'),axis=1,inplace=True)

# %%
print(f"Shape of input ==> X :{X.shape}\nShape of output ==> Y :{y.shape} ")
# Out:
# Shape of input ==> X :(205, 15)
# Shape of output ==> Y :(205,)

# %%
X_train=X.sample(frac=0.7, replace=True, random_state=1,axis=0)
y_train=y.sample(frac=0.7, replace=True, random_state=1,axis=0)

# %%
X_test=X.sample(frac=0.3, replace=True, random_state=1,axis=0)
y_test=y.sample(frac=0.3, replace=True, random_state=1,axis=0)

# %%
print(f"shape of training data is :{X_train.shape}\nshape of training label is :{y_train.shape}\nshape of testing data is :{X_test.shape}\nshape of testing label is :{y_test.shape}")
# Out:
# shape of training data is :(144, 15)
# shape of training label is :(144,)
# shape of testing data is :(62, 15)
# shape of testing label is :(62,)

# %%
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")

# %%
mean = X_train.mean(axis=0)
X_train-= mean
std = X_train.std(axis=0)
X_train/= std
X_test-= mean
X_test/= std

# %%
y_mean = y_train.mean(axis=0)
y_train-= y_mean
y_std = y_train.std(axis=0)
y_train/= y_std
y_test-= y_mean
y_test/= y_std

# %%
val_x=X_train[:30]
partial_x_train=X_train[30:]
val_y=y_train[:30]
partial_y_train=y_train[30:]

# %%
import tensorflow as tf
from keras import models,layers,optimizers,losses
network=models.Sequential()
network.add(layers.Dense(10,activation="relu" ,input_shape=(X_train.shape[1],)))
network.add(layers.Dropout(0.2))
network.add(layers.Dense(8,activation="relu"))
#network.add(layers.Dropout(0.2))
network.add(layers.Dense(6,activation="relu"))
network.add(layers.Dense(1))
network.compile(optimizer="rmsprop",loss="mse",metrics=["mae"])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                160
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 309
# Trainable params: 309
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=network.fit(partial_x_train, partial_y_train,epochs=45, batch_size=1, verbose=1,validation_data=(val_x,val_y))
# Out:
# Epoch 1/45
# 114/114 [==============================] - 1s 5ms/step - loss: 1.3742 - mae: 0.7665 - val_loss: 0.9595 - val_mae: 0.6674
# Epoch 2/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.3612 - mae: 0.4044 - val_loss: 0.7809 - val_mae: 0.6210
# Epoch 3/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.7324 - mae: 0.4889 - val_loss: 0.6328 - val_mae: 0.5697
# Epoch 4/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.7842 - mae: 0.5691 - val_loss: 0.5851 - val_mae: 0.5081
# Epoch 5/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.5116 - mae: 0.4426 - val_loss: 0.5277 - val_mae: 0.4958
# Epoch 6/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.4460 - mae: 0.4637 - val_loss: 0.4883 - val_mae: 0.4861
# Epoch 7/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.6373 - mae: 0.4390 - val_loss: 0.4926 - val_mae: 0.4894
# Epoch 8/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.6048 - mae: 0.4762 - val_loss: 0.4531 - val_mae: 0.4421
# Epoch 9/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.3206 - mae: 0.3236 - val_loss: 0.4298 - val_mae: 0.4690
# Epoch 10/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.5718 - mae: 0.4478 - val_loss: 0.4125 - val_mae: 0.4247
# Epoch 11/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.3963 - mae: 0.3944 - val_loss: 0.4099 - val_mae: 0.4554
# Epoch 12/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.4013 - mae: 0.3469 - val_loss: 0.3864 - val_mae: 0.4459
# Epoch 13/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2748 - mae: 0.3555 - val_loss: 0.3732 - val_mae: 0.4292
# Epoch 14/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2469 - mae: 0.2808 - val_loss: 0.3629 - val_mae: 0.4370
# Epoch 15/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.3249 - mae: 0.3639 - val_loss: 0.3676 - val_mae: 0.4421
# Epoch 16/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.3634 - mae: 0.3810 - val_loss: 0.3777 - val_mae: 0.4492
# Epoch 17/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2584 - mae: 0.3442 - val_loss: 0.3573 - val_mae: 0.4327
# Epoch 18/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2660 - mae: 0.3287 - val_loss: 0.3433 - val_mae: 0.4062
# Epoch 19/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1717 - mae: 0.2778 - val_loss: 0.3504 - val_mae: 0.4222
# Epoch 20/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.2182 - mae: 0.3180 - val_loss: 0.3679 - val_mae: 0.4589
# Epoch 21/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2733 - mae: 0.3536 - val_loss: 0.3593 - val_mae: 0.4385
# Epoch 22/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1825 - mae: 0.2992 - val_loss: 0.3676 - val_mae: 0.4582
# Epoch 23/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1654 - mae: 0.2919 - val_loss: 0.3321 - val_mae: 0.3876
# Epoch 24/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2381 - mae: 0.3038 - val_loss: 0.3256 - val_mae: 0.3820
# Epoch 25/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1377 - mae: 0.2198 - val_loss: 0.3396 - val_mae: 0.4068
# Epoch 26/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1660 - mae: 0.2870 - val_loss: 0.3683 - val_mae: 0.4662
# Epoch 27/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1522 - mae: 0.2664 - val_loss: 0.3348 - val_mae: 0.4180
# Epoch 28/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1678 - mae: 0.2751 - val_loss: 0.3098 - val_mae: 0.3778
# Epoch 29/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2618 - mae: 0.3567 - val_loss: 0.3388 - val_mae: 0.4143
# Epoch 30/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1519 - mae: 0.2216 - val_loss: 0.3339 - val_mae: 0.4191
# Epoch 31/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1669 - mae: 0.2877 - val_loss: 0.3368 - val_mae: 0.4153
# Epoch 32/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1203 - mae: 0.2470 - val_loss: 0.3253 - val_mae: 0.4110
# Epoch 33/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1144 - mae: 0.2403 - val_loss: 0.3101 - val_mae: 0.3905
# Epoch 34/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2758 - mae: 0.3151 - val_loss: 0.3109 - val_mae: 0.3821
# Epoch 35/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1553 - mae: 0.2468 - val_loss: 0.3038 - val_mae: 0.3733
# Epoch 36/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1879 - mae: 0.2784 - val_loss: 0.3266 - val_mae: 0.4028
# Epoch 37/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1161 - mae: 0.2169 - val_loss: 0.3083 - val_mae: 0.3715
# Epoch 38/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.4856 - mae: 0.3407 - val_loss: 0.3502 - val_mae: 0.4241
# Epoch 39/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1257 - mae: 0.2441 - val_loss: 0.3211 - val_mae: 0.3872
# Epoch 40/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1964 - mae: 0.2734 - val_loss: 0.3138 - val_mae: 0.3900
# Epoch 41/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.1345 - mae: 0.2381 - val_loss: 0.2931 - val_mae: 0.3712
# Epoch 42/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.2328 - mae: 0.2725 - val_loss: 0.3141 - val_mae: 0.4204
# Epoch 43/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.0551 - mae: 0.1681 - val_loss: 0.2940 - val_mae: 0.3702
# Epoch 44/45
# 114/114 [==============================] - 0s 2ms/step - loss: 0.3319 - mae: 0.3404 - val_loss: 0.3036 - val_mae: 0.4170
# Epoch 45/45
# 114/114 [==============================] - 0s 1ms/step - loss: 0.1466 - mae: 0.2315 - val_loss: 0.2990 - val_mae: 0.3924

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss,"go",label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
network.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1990 - mae: 0.3059
# [0.19900648295879364, 0.30593422055244446]

# %%
result_1=network.predict(X_test)
result_1[5]
# Out:
# array([0.36450484], dtype=float32)

# %%
y=result_1
y1=range(62)
x=y_test
plt.scatter(x, y1, label= "Actual price", color= "purple", marker= "*", s=50)
plt.scatter(y, y1, label= "Predicted Price", color= "orange", marker= ".", s=50)
plt.xlabel('Price')
plt.ylabel('Rows')
plt.title('Actual price vs predicted price!')
plt.legend()
plt.grid()
plt.show()
