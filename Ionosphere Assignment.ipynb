# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv("/content/gdrive/MyDrive/ionosphere_data.csv")
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df1 =df['label']
df1.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
df.sample(3)
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 325         1         0   0.89563  ...    0.60073    0.08660      g
# 178         1         0   0.18590  ...    0.16827    0.19551      b
# 81          0         0   1.00000  ...    1.00000   -1.00000      b
#
# [3 rows x 35 columns]

# %%
df.drop_duplicates()
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [350 rows x 35 columns]

# %%
df.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
data=df.iloc[:,:-1]
label=df.iloc[:,-1]

# %%
label = df["label"].map({'g':1,'b':0})

# %%
X_train=data.sample(frac=0.6,random_state=1)
X_test=data.sample(frac=0.4,random_state=1)
y_train=label.sample(frac=0.6,random_state=1)
y_test=label.sample(frac=0.4,random_state=1)

# %%
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")

# %%
from keras import models, layers , optimizers ,regularizers,losses
network=models.Sequential()
network.add(layers.Dense(16,activation="relu",input_shape=(X_train.shape[1],)))
#network.add(layers.Dense(8,kernel_regularizer=regularizers.l2(0.0001),activation="relu"))
network.add(layers.Dense(1,activation="sigmoid"))
network.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=["accuracy"])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = network.fit(X_train,y_train,epochs=50,batch_size=1,verbose=1)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 1s 1ms/step - loss: 0.6047 - accuracy: 0.6970
# Epoch 2/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7343
# Epoch 3/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.4946 - accuracy: 0.7915
# Epoch 4/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8564
# Epoch 5/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3589 - accuracy: 0.8857
# Epoch 6/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.8983
# Epoch 7/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8995
# Epoch 8/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.8599
# Epoch 9/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.8830
# Epoch 10/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2993 - accuracy: 0.9240
# Epoch 11/50
# 211/211 [==============================] - 0s 958us/step - loss: 0.3312 - accuracy: 0.8893
# Epoch 12/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2513 - accuracy: 0.9096
# Epoch 13/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.9254
# Epoch 14/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1630 - accuracy: 0.9537
# Epoch 15/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1729 - accuracy: 0.9586
# Epoch 16/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1344 - accuracy: 0.9558
# Epoch 17/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1937 - accuracy: 0.9472
# Epoch 18/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.9515
# Epoch 19/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9263
# Epoch 20/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1243 - accuracy: 0.9658
# Epoch 21/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9634
# Epoch 22/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1868 - accuracy: 0.9113
# Epoch 23/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1670 - accuracy: 0.9430
# Epoch 24/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1647 - accuracy: 0.9385
# Epoch 25/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9139
# Epoch 26/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1517 - accuracy: 0.9436
# Epoch 27/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.9688
# Epoch 28/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.9730
# Epoch 29/50
# 211/211 [==============================] - 0s 999us/step - loss: 0.1753 - accuracy: 0.9442
# Epoch 30/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2043 - accuracy: 0.9347
# Epoch 31/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.9430
# Epoch 32/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1524 - accuracy: 0.9538
# Epoch 33/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1214 - accuracy: 0.9645
# Epoch 34/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9621
# Epoch 35/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1349 - accuracy: 0.9605
# Epoch 36/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2225 - accuracy: 0.9470
# Epoch 37/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9720
# Epoch 38/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1216 - accuracy: 0.9612
# Epoch 39/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9695
# Epoch 40/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1487 - accuracy: 0.9585
# Epoch 41/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1150 - accuracy: 0.9670
# Epoch 42/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0960 - accuracy: 0.9647
# Epoch 43/50
# 211/211 [==============================] - 0s 999us/step - loss: 0.0471 - accuracy: 0.9820
# Epoch 44/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1329 - accuracy: 0.9577
# Epoch 45/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9628
# Epoch 46/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9695
# Epoch 47/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1355 - accuracy: 0.9547
# Epoch 48/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9523
# Epoch 49/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9855
# Epoch 50/50
# 211/211 [==============================] - 0s 996us/step - loss: 0.0755 - accuracy: 0.9733

# %%
history_dict = history.history
history_dict.keys()
[u'accuracy', u'loss']
# Out:
# ['accuracy', 'loss']

# %%
loss_acc=pd.DataFrame(history.history)
loss_acc.tail().T
# Out:
#                 45        46        47        48        49
# loss      0.111003  0.117091  0.106277  0.112678  0.103206
# accuracy  0.962085  0.957346  0.962085  0.966825  0.962085

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
accuracy_values = history_dict['accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)
plt.plot(epochs, loss_values, 'g', label='loss')
plt.plot(epochs, accuracy_values, 'b', label='accuracy')
plt.title('Accuracy & Loss ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
network.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9786
# [0.05410397797822952, 0.9785714149475098]

# %%
pred=network.predict(X_test)
pred.flatten().astype("U8")
# Out:
# array(['0.004723', '0.998280', '2.694480', '0.999296', '0.924928',
#        '0.998615', '0.997823', '0.936813', '0.000734', '0.063667',
#        '0.992893', '0.998601', '0.006259', '0.992000', '5.458554',
#        '0.001119', '0.840783', '0.008057', '0.985688', '0.000867',
#        '0.473547', '0.939941', '0.995617', '0.895078', '4.923913',
#        '0.998892', '0.983804', '0.996897', '0.909612', '0.997368',
#        '0.001640', '0.998469', '0.000232', '0.599422', '0.995203',
#        '0.999162', '0.044083', '1.713603', '0.998119', '0.999621',
#        '0.975992', '0.988371', '0.992297', '0.990203', '0.999311',
#        '0.852389', '0.996559', '0.994403', '0.037540', '0.997487',
#        '0.940190', '0.999319', '0.025904', '0.004126', '0.999843',
#        '0.996209', '0.003412', '1.460573', '4.317775', '0.996904',
#        '0.994507', '0.001416', '0.998761', '0.001038', '0.000951',
#        '0.997680', '3.810465', '0.999577', '0.996401', '3.503338',
#        '0.996131', '0.023236', '0.002067', '0.997401', '0.005373',
#        '8.331731', '0.998411', '0.997009', '0.993745', '0.963726',
#        '0.968436', '0.999977', '0.989420', '0.999676', '0.999099',
#        '0.999305', '0.987704', '0.982973', '0.951090', '0.993395',
#        '0.983645', '5.023187', '5.317269', '0.981734', '0.996073',
#        '0.001033', '0.995273', '0.995219', '0.987635', '0.990821',
#        '0.996657', '0.000237', '0.979883', '0.995117', '0.997999',
#        '0.844428', '3.497411', '0.994891', '0.999782', '0.998738',
#        '0.999360', '0.995507', '0.680392', '0.995774', '0.999452',
#        '0.972278', '0.000412', '0.995320', '2.752995', '0.982121',
#        '0.998337', '0.928463', '2.099559', '0.969207', '0.970219',
#        '0.008302', '0.946943', '0.000197', '0.998909', '0.998628',
#        '0.997484', '0.999634', '0.858483', '0.009095', '0.999118',
#        '0.009010', '0.984073', '2.139896', '0.998118', '2.592283'],
#       dtype='<U8')
